# %% [markdown]
# # Studi Kasus #1
#
# Load data untuk dibuka

# %%
import pandas as pd

# %%
# Load data secara lokal di folder yang sama
pd.read_csv("Student_Marks.csv")

# Load data secara lokal di folder yang tempat yang lebih dalam dibanding file program
# pd.read_csv("dataset/Student_Marks.csv")

# Load data secara lokal dengan path penuhnya
# pd.read_csv(r"D:\DokumenFaisal\DokumenFTDS014\Learning_Stuff\Phase_0\Week_1\Student_Marks.csv")
# Out:
#     number_courses  time_study   Marks
# 0                3       4.508  19.202
# 1                4       0.096   7.734
# 2                4       3.133  13.811
# 3                6       7.909  53.018
# 4                8       7.811  55.299
# ..             ...         ...     ...
# 95               6       3.561  19.128
# 96               3       0.301   5.609
# 97               4       7.163  41.444
# 98               7       0.309  12.027
# 99               3       6.335  32.357
#
# [100 rows x 3 columns]

# %%
# Load data secara lokal yang separatornya bukan menggunakan tanda koma (,)

pd.read_csv("ref.csv", delimiter = ";") # delimiter bisa diganti dengan sep
# Out:
#    ch1  ch2  ch3
# 0   10    1  100
# 1   20    2  200
# 2   30    3  300
# 3   40    4  400
# 4   50    5  500

# %%
# Load data dari server

pd.read_csv("https://raw.githubusercontent.com/ardhiraka/PFDS_sources/master/nbaallelo.csv")
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id  date_game  \
# 0               1  194611010TRH   NBA        0     1947  11/1/1946
# 1               1  194611010TRH   NBA        1     1947  11/1/1946
# 2               2  194611020CHS   NBA        0     1947  11/2/1946
# 3               2  194611020CHS   NBA        1     1947  11/2/1946
# 4               3  194611020DTF   NBA        0     1947  11/2/1946
# ...           ...           ...   ...      ...      ...        ...
# 126309      63155  201506110CLE   NBA        0     2015  6/11/2015
# 126310      63156  201506140GSW   NBA        0     2015  6/14/2015
# 126311      63156  201506140GSW   NBA        1     2015  6/14/2015
# 126312      63157  201506170CLE   NBA        0     2015  6/16/2015
# 126313      63157  201506170CLE   NBA        1     2015  6/16/2015
#
#         seasongame  is_playoffs team_id    fran_id  ...  win_equiv  opp_id  \
# 0                1            0     TRH    Huskies  ...  40.294830     NYK
# ...

# %% [markdown]
# Untuk membuka .csv di dalam Google Collab, klik simbol folder di bagian kiri, lalu bisa upload dokumen yang ingin dibuka di sana. Dokumen di Google Collab ini akan dihapus apabila tidak ada modifikasi yang dilakukan terhadap file tersebut. 3 langkah di atas juga dapat diterapkan untuk memanggil dokumen ke dalam program yang sedang dikerjakan.

# %% [markdown]
# Untuk sekarang, load file 'nbaallelo.csv' ke dalam variabel baru.

# %%
df = pd.read_csv("https://raw.githubusercontent.com/ardhiraka/PFDS_sources/master/nbaallelo.csv")
print(df)
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id  date_game  \
# 0               1  194611010TRH   NBA        0     1947  11/1/1946
# 1               1  194611010TRH   NBA        1     1947  11/1/1946
# 2               2  194611020CHS   NBA        0     1947  11/2/1946
# 3               2  194611020CHS   NBA        1     1947  11/2/1946
# 4               3  194611020DTF   NBA        0     1947  11/2/1946
# ...           ...           ...   ...      ...      ...        ...
# 126309      63155  201506110CLE   NBA        0     2015  6/11/2015
# 126310      63156  201506140GSW   NBA        0     2015  6/14/2015
# 126311      63156  201506140GSW   NBA        1     2015  6/14/2015
# 126312      63157  201506170CLE   NBA        0     2015  6/16/2015
# 126313      63157  201506170CLE   NBA        1     2015  6/16/2015
#
#         seasongame  is_playoffs team_id    fran_id  ...  win_equiv  opp_id  \
# 0                1            0     TRH    Huskies  ...  40.294830     NYK
# ...

# %%
# Untuk melihat sekilas data yang akan ditampilkan dari atas

pd.set_option("display.max.columns", None)
df.head()
# Out:
#    gameorder       game_id lg_id  _iscopy  year_id  date_game  seasongame  \
# 0          1  194611010TRH   NBA        0     1947  11/1/1946           1
# 1          1  194611010TRH   NBA        1     1947  11/1/1946           1
# 2          2  194611020CHS   NBA        0     1947  11/2/1946           1
# 3          2  194611020CHS   NBA        1     1947  11/2/1946           2
# 4          3  194611020DTF   NBA        0     1947  11/2/1946           1
#
#    is_playoffs team_id  fran_id  pts      elo_i      elo_n  win_equiv opp_id  \
# 0            0     TRH  Huskies   66  1300.0000  1293.2767  40.294830    NYK
# 1            0     NYK   Knicks   68  1300.0000  1306.7233  41.705170    TRH
# 2            0     CHS    Stags   63  1300.0000  1309.6521  42.012257    NYK
# 3            0     NYK   Knicks   47  1306.7233  1297.0712  40.692783    CHS
# 4            0     DTF  Falcons   33  1300.0000  1279.6189  38.864048    WSC
#
# ...

# %%
# Untuk melihat sekilas data yang akan ditampilkan dari bawah

df.tail()
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id  date_game  \
# 126309      63155  201506110CLE   NBA        0     2015  6/11/2015
# 126310      63156  201506140GSW   NBA        0     2015  6/14/2015
# 126311      63156  201506140GSW   NBA        1     2015  6/14/2015
# 126312      63157  201506170CLE   NBA        0     2015  6/16/2015
# 126313      63157  201506170CLE   NBA        1     2015  6/16/2015
#
#         seasongame  is_playoffs team_id    fran_id  pts      elo_i      elo_n  \
# 126309         100            1     CLE  Cavaliers   82  1723.4149  1704.3949
# 126310         102            1     GSW   Warriors  104  1809.9791  1813.6349
# 126311         101            1     CLE  Cavaliers   91  1704.3949  1700.7391
# 126312         102            1     CLE  Cavaliers   97  1700.7391  1692.0859
# 126313         103            1     GSW   Warriors  105  1813.6349  1822.2881
#
#         win_equiv opp_id   opp_fran  opp_pts  opp_elo_i  opp_elo_n  \
# ...

# %%
# Untuk melihat data acak

df.sample(10)
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id   date_game  \
# 20836       10419  197002170NOB   ABA        1     1970   2/17/1970
# 61184       30593  198903070GSW   NBA        0     1989    3/7/1989
# 82886       41444  199803100DEN   NBA        0     1998   3/10/1998
# 106039      53020  200711170IND   NBA        1     2008  11/17/2007
# 102645      51323  200603300LAL   NBA        1     2006   3/30/2006
# 17225        8613  196810260SFW   NBA        1     1969  10/26/1968
# 96336       48169  200401070NOH   NBA        0     2004    1/7/2004
# 119898      59950  201302080CLE   NBA        1     2013    2/8/2013
# 117178      58590  201202170OKC   NBA        1     2012   2/17/2012
# 92437       46219  200204050CHI   NBA        0     2002    4/5/2002
#
#         seasongame  is_playoffs team_id   fran_id  pts      elo_i      elo_n  \
# 20836           55            0     DLC     Spurs  122  1445.5258  1452.8818
# ...

# %%
# Untuk melihat informasi entri data, nilai yang hilang, dan jenis data di setiap kolomnya.

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 126314 entries, 0 to 126313
# Data columns (total 23 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   gameorder      126314 non-null  int64
#  1   game_id        126314 non-null  object
#  2   lg_id          126314 non-null  object
#  3   _iscopy        126314 non-null  int64
#  4   year_id        126314 non-null  int64
#  5   date_game      126314 non-null  object
#  6   seasongame     126314 non-null  int64
#  7   is_playoffs    126314 non-null  int64
#  8   team_id        126314 non-null  object
#  9   fran_id        126314 non-null  object
#  10  pts            126314 non-null  int64
#  11  elo_i          126314 non-null  float64
#  12  elo_n          126314 non-null  float64
#  13  win_equiv      126314 non-null  float64
#  14  opp_id         126314 non-null  object
#  15  opp_fran       126314 non-null  object
#  16  opp_pts        126314 non-null  int64
# ...

# %%
# Untuk mengecek data numerik yang ada di setiap kolom
# Bisa ditambah perintah .T untuk mentranspos data yang dipanggil

df.describe().T
# Out:
#                 count          mean           std          min           25%  \
# gameorder    126314.0  31579.000000  18231.927643     1.000000  15790.000000
# _iscopy      126314.0      0.500000      0.500002     0.000000      0.000000
# year_id      126314.0   1988.200374     17.582309  1947.000000   1975.000000
# seasongame   126314.0     43.533733     25.375178     1.000000     22.000000
# is_playoffs  126314.0      0.063857      0.244499     0.000000      0.000000
# pts          126314.0    102.729982     14.814845     0.000000     93.000000
# elo_i        126314.0   1495.236055    112.139945  1091.644500   1417.237975
# elo_n        126314.0   1495.236055    112.461687  1085.774400   1416.994900
# win_equiv    126314.0     41.707889     10.627332    10.152501     34.103035
# opp_pts      126314.0    102.729982     14.814845     0.000000     93.000000
# opp_elo_i    126314.0   1495.236055    112.139945  1091.644500   1417.237975
# ...

# %% [markdown]
# Contoh overview insight:
#
# Berdasarkan hasil overview data yang terlah dilakukan, diketahui bahwa:
# 1. Terdapat *missing value* pada kolom "notes"
# 2. Pertandingan telah direkam mulai dari tahun 1947 sampai 2015
# 3. Terdapat tim yang menyelesaikan pertandingan dengan mencetak 0 poin
# 4. dst.

# %% [markdown]
# ## Exploratory Data Analysis (EDA)

# %%
df.head(2)
# Out:
#    gameorder       game_id lg_id  _iscopy  year_id  date_game  seasongame  \
# 0          1  194611010TRH   NBA        0     1947  11/1/1946           1
# 1          1  194611010TRH   NBA        1     1947  11/1/1946           1
#
#    is_playoffs team_id  fran_id  pts   elo_i      elo_n  win_equiv opp_id  \
# 0            0     TRH  Huskies   66  1300.0  1293.2767   40.29483    NYK
# 1            0     NYK   Knicks   68  1300.0  1306.7233   41.70517    TRH
#
#   opp_fran  opp_pts  opp_elo_i  opp_elo_n game_location game_result  forecast  \
# 0   Knicks       68     1300.0  1306.7233             H           L  0.640065
# 1  Huskies       66     1300.0  1293.2767             A           W  0.359935
#
#   notes
# 0   NaN
# 1   NaN

# %%
# Data dapat dislice sama seperti jenis data array yang lain.

df["team_id"]
# Out:
# 0         TRH
# 1         NYK
# 2         CHS
# 3         NYK
# 4         DTF
#          ...
# 126309    CLE
# 126310    GSW
# 126311    CLE
# 126312    CLE
# 126313    GSW
# Name: team_id, Length: 126314, dtype: object

# %%
# Jika ingin menampilkan lebih dari dua variabel, manipulasi dengan membuatnya menjadi array.

df[["team_id", "fran_id"]].head()
# Out:
#   team_id  fran_id
# 0     TRH  Huskies
# 1     NYK   Knicks
# 2     CHS    Stags
# 3     NYK   Knicks
# 4     DTF  Falcons

# %%
# Melihat 5 tim dengan kemunculan paling banyak

print(df["team_id"].value_counts().head())
print(df["fran_id"].value_counts().head())
# Out:
# BOS    5997
# NYK    5769
# LAL    5078
# DET    4985
# PHI    4533
# Name: team_id, dtype: int64
# Lakers      6024
# Celtics     5997
# Knicks      5769
# Warriors    5657
# Pistons     5650
# Name: fran_id, dtype: int64

# %% [markdown]
# Terdapat adanya inkonsistensi frekuensi kemunculan label berdasarkan 'team_id' dan 'fran_id'. Lakukan pengecekan data untuk Lakers dan LAL

# %%
df.head(2)
# Out:
#    gameorder       game_id lg_id  _iscopy  year_id  date_game  seasongame  \
# 0          1  194611010TRH   NBA        0     1947  11/1/1946           1
# 1          1  194611010TRH   NBA        1     1947  11/1/1946           1
#
#    is_playoffs team_id  fran_id  pts   elo_i      elo_n  win_equiv opp_id  \
# 0            0     TRH  Huskies   66  1300.0  1293.2767   40.29483    NYK
# 1            0     NYK   Knicks   68  1300.0  1306.7233   41.70517    TRH
#
#   opp_fran  opp_pts  opp_elo_i  opp_elo_n game_location game_result  forecast  \
# 0   Knicks       68     1300.0  1306.7233             H           L  0.640065
# 1  Huskies       66     1300.0  1293.2767             A           W  0.359935
#
#   notes
# 0   NaN
# 1   NaN

# %%
df.loc[df["fran_id"] == "Lakers", ["team_id", "fran_id"]].value_counts()
# Out:
# team_id  fran_id
# LAL      Lakers     5078
# MNL      Lakers      946
# dtype: int64

# %%
df["team_id"].value_counts().head()
# Out:
# BOS    5997
# NYK    5769
# LAL    5078
# DET    4985
# PHI    4533
# Name: team_id, dtype: int64

# %%
df["fran_id"].value_counts().head()
# Out:
# Lakers      6024
# Celtics     5997
# Knicks      5769
# Warriors    5657
# Pistons     5650
# Name: fran_id, dtype: int64

# %% [markdown]
# Dari eksplorasi data, diketahui bahwa inkonsistensi data pada Lakers terjadi karena adanya pergantian 'team_id' yang merepresentasikan Lakers dari MNL ke LAL. ....

# %%
# Menggandengkan dengan agregasi

df.loc[df["fran_id"] == "Lakers", "pts"].max()
# Out:
# 162

# %% [markdown]
# ## Query

# %%
df.head()
# Out:
#    gameorder       game_id lg_id  _iscopy  year_id  date_game  seasongame  \
# 0          1  194611010TRH   NBA        0     1947  11/1/1946           1
# 1          1  194611010TRH   NBA        1     1947  11/1/1946           1
# 2          2  194611020CHS   NBA        0     1947  11/2/1946           1
# 3          2  194611020CHS   NBA        1     1947  11/2/1946           2
# 4          3  194611020DTF   NBA        0     1947  11/2/1946           1
#
#    is_playoffs team_id  fran_id  pts      elo_i      elo_n  win_equiv opp_id  \
# 0            0     TRH  Huskies   66  1300.0000  1293.2767  40.294830    NYK
# 1            0     NYK   Knicks   68  1300.0000  1306.7233  41.705170    TRH
# 2            0     CHS    Stags   63  1300.0000  1309.6521  42.012257    NYK
# 3            0     NYK   Knicks   47  1306.7233  1297.0712  40.692783    CHS
# 4            0     DTF  Falcons   33  1300.0000  1279.6189  38.864048    WSC
#
# ...

# %%
df[(df["year_id"] > 2000) &
(df["year_id"] <= 2010) &
(df["fran_id"] == "Hawks") &
(df["game_result"] == "W")]
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id   date_game  \
# 87955       43978  200011140ATL   NBA        0     2001  11/14/2000
# 88067       44034  200011220ATL   NBA        0     2001  11/22/2000
# 88163       44082  200011280WAS   NBA        1     2001  11/28/2000
# 88214       44108  200012020ATL   NBA        0     2001   12/2/2000
# 88356       44179  200012120ATL   NBA        0     2001  12/12/2000
# ...           ...           ...   ...      ...      ...         ...
# 113465      56733  201004140ATL   NBA        0     2010   4/14/2010
# 113493      56747  201004170ATL   NBA        0     2010   4/17/2010
# 113512      56757  201004200ATL   NBA        0     2010   4/20/2010
# 113575      56788  201004300MIL   NBA        1     2010   4/30/2010
# 113582      56792  201005020ATL   NBA        0     2010    5/2/2010
#
#         seasongame  is_playoffs team_id fran_id  pts      elo_i      elo_n  \
# ...

# %%
# Latihan: Buatlah Query dengan syarat berikut:
# year_id [1995 - 2015]
# seasongame ganjil
# fran_id Celtics
# game_location H
# pts > 90

df[(df["year_id"] >= 1995)&
(df["year_id"] <= 2015) &
(df["seasongame"] % 2 != 0) &
(df["fran_id"] == "Celtics") &
(df["game_location"] == "H") &
(df["pts"] > 90)].shape
# Out:
# (359, 23)

# %%
# Buat Query di atas dengan perintah .query

df.query("year_id >= 1995 & \
    year_id <= 2015 & \
    seasongame % 2 != 0 & \
    fran_id == 'Celtics' & \
    game_location == 'H' & \
     pts > 90").shape
# Out:
# (359, 23)

# %% [markdown]
# ## Group by and Aggregating

# %%
df.head()
# Out:
#    gameorder       game_id lg_id  _iscopy  year_id  date_game  seasongame  \
# 0          1  194611010TRH   NBA        0     1947  11/1/1946           1
# 1          1  194611010TRH   NBA        1     1947  11/1/1946           1
# 2          2  194611020CHS   NBA        0     1947  11/2/1946           1
# 3          2  194611020CHS   NBA        1     1947  11/2/1946           2
# 4          3  194611020DTF   NBA        0     1947  11/2/1946           1
#
#    is_playoffs team_id  fran_id  pts      elo_i      elo_n  win_equiv opp_id  \
# 0            0     TRH  Huskies   66  1300.0000  1293.2767  40.294830    NYK
# 1            0     NYK   Knicks   68  1300.0000  1306.7233  41.705170    TRH
# 2            0     CHS    Stags   63  1300.0000  1309.6521  42.012257    NYK
# 3            0     NYK   Knicks   47  1306.7233  1297.0712  40.692783    CHS
# 4            0     DTF  Falcons   33  1300.0000  1279.6189  38.864048    WSC
#
# ...

# %%
# Kelompokkan data tabel di atas berdasarkan "fran_id"
# Lalu lakukan fungsi aritmatika pada "pts"

df.groupby(by = "fran_id")[["pts"]].mean()
# Out:
#                      pts
# fran_id
# Baltimore      79.698073
# Bombers        71.457831
# Bucks         103.700050
# Bulls         101.525192
# Capitols       76.931271
# Cavaliers      99.846719
# Celtics       104.466233
# Clippers      101.934905
# Colonels      111.625296
# Condors       115.446512
# Denver         77.709677
# Falcons        63.283333
# Floridians    112.654545
# Grizzlies      95.161738
# Hawks         101.805635
# Heat           96.627162
# Hornets        94.506711
# Huskies        66.583333
# Ironmen        61.233333
# Jazz          102.153305
# Jets           74.700000
# Kings         103.971689
# Knicks        100.970185
# Lakers        105.817397
# Magic          99.427277
# Mavericks     102.634915
# Nets          101.755723
# Nuggets       108.199029
# Olympians      81.078014
# Pacers        103.687722
# Packers        86.013889
# Pelicans       97.956522
# Pistons       101.373097
# Raptors        96.921665
# Rebels         71.015873
# ...

# %%
df.groupby(by = "fran_id")[["pts"]].mean().sort_values(by = "pts", ascending = True)
# Out:
#                      pts
# fran_id
# Ironmen        61.233333
# Falcons        63.283333
# Huskies        66.583333
# Rebels         71.015873
# Bombers        71.457831
# Steamrollers   73.642857
# Jets           74.700000
# Capitols       76.931271
# Denver         77.709677
# Stags          78.453846
# Waterloo       79.370968
# Baltimore      79.698073
# Olympians      81.078014
# Redskins       82.646154
# Packers        86.013889
# Hornets        94.506711
# Grizzlies      95.161738
# Heat           96.627162
# Raptors        96.921665
# Timberwolves   97.462694
# Pelicans       97.956522
# Magic          99.427277
# Cavaliers      99.846719
# Knicks        100.970185
# Pistons       101.373097
# Bulls         101.525192
# Nets          101.755723
# Hawks         101.805635
# Clippers      101.934905
# Jazz          102.153305
# Mavericks     102.634915
# Wizards       103.624836
# Pacers        103.687722
# Bucks         103.700050
# Sixers        103.807760
# ...

# %%
# Breakdown cara kerja
df.groupby(by = "game_location")["pts"].mean()
# Out:
# game_location
# A    100.856616
# H    104.602395
# N    104.315789
# Name: pts, dtype: float64

# %%
# Contoh
df.groupby(by = "game_location")
grup = df.groupby(by = "game_location")

# %%
grup.get_group("A")
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id  date_game  \
# 1               1  194611010TRH   NBA        1     1947  11/1/1946
# 3               2  194611020CHS   NBA        1     1947  11/2/1946
# 5               3  194611020DTF   NBA        1     1947  11/2/1946
# 6               4  194611020PRO   NBA        1     1947  11/2/1946
# 8               5  194611020STB   NBA        1     1947  11/2/1946
# ...           ...           ...   ...      ...      ...        ...
# 126304      63153  201506070GSW   NBA        1     2015   6/7/2015
# 126306      63154  201506090CLE   NBA        1     2015   6/9/2015
# 126308      63155  201506110CLE   NBA        1     2015  6/11/2015
# 126311      63156  201506140GSW   NBA        1     2015  6/14/2015
# 126313      63157  201506170CLE   NBA        1     2015  6/16/2015
#
#         seasongame  is_playoffs team_id    fran_id  pts      elo_i      elo_n  \
# 1                1            0     NYK     Knicks   68  1300.0000  1306.7233
# ...

# %%
grup.get_group("H")
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id  date_game  \
# 0               1  194611010TRH   NBA        0     1947  11/1/1946
# 2               2  194611020CHS   NBA        0     1947  11/2/1946
# 4               3  194611020DTF   NBA        0     1947  11/2/1946
# 7               4  194611020PRO   NBA        0     1947  11/2/1946
# 9               5  194611020STB   NBA        0     1947  11/2/1946
# ...           ...           ...   ...      ...      ...        ...
# 126305      63153  201506070GSW   NBA        0     2015   6/7/2015
# 126307      63154  201506090CLE   NBA        0     2015   6/9/2015
# 126309      63155  201506110CLE   NBA        0     2015  6/11/2015
# 126310      63156  201506140GSW   NBA        0     2015  6/14/2015
# 126312      63157  201506170CLE   NBA        0     2015  6/16/2015
#
#         seasongame  is_playoffs team_id       fran_id  pts      elo_i  \
# 0                1            0     TRH       Huskies   66  1300.0000
# ...

# %%
grup.get_group("N")
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id   date_game  \
# 64302       32152  199011020UTA   NBA        1     1991   11/2/1990
# 64303       32152  199011020UTA   NBA        0     1991   11/2/1990
# 64318       32160  199011030PHO   NBA        1     1991   11/3/1990
# 64319       32160  199011030PHO   NBA        0     1991   11/3/1990
# 69000       34501  199211060HOU   NBA        0     1993   11/6/1992
# 69001       34501  199211060HOU   NBA        1     1993   11/6/1992
# 69030       34516  199211070SEA   NBA        1     1993   11/7/1992
# 69031       34516  199211070SEA   NBA        0     1993   11/7/1992
# 73736       36869  199411040LAC   NBA        0     1995   11/4/1994
# 73737       36869  199411040LAC   NBA        1     1995   11/4/1994
# 73766       36884  199411050POR   NBA        1     1995   11/5/1994
# 73767       36884  199411050POR   NBA        0     1995   11/5/1994
# 78694       39348  199611070NJN   NBA        1     1997   11/7/1996
# ...

# %%
grup.get_group("A")["pts"]
# Out:
# 1          68
# 3          47
# 5          50
# 6          53
# 8          51
#          ...
# 126304     95
# 126306     91
# 126308    103
# 126311     91
# 126313    105
# Name: pts, Length: 63138, dtype: int64

# %%
grup.get_group("H")["pts"]
# Out:
# 0          66
# 2          63
# 4          33
# 7          59
# 9          56
#          ...
# 126305     93
# 126307     96
# 126309     82
# 126310    104
# 126312     97
# Name: pts, Length: 63138, dtype: int64

# %%
grup.get_group("N")["pts"]
# Out:
# 64302     119
# 64303      96
# 64318     102
# 64319     101
# 69000      94
# 69001     111
# 69030      85
# 69031      89
# 73736     121
# 73737     100
# 73766     112
# 73767      95
# 78694     108
# 78695      95
# 78714      82
# 78715      86
# 81624     108
# 81625     106
# 85290     100
# 85291      95
# 85302     114
# 85303     101
# 95378     109
# 95379     100
# 95384     105
# 95385     124
# 115490    116
# 115491    103
# 115504    136
# 115505    137
# 119582     87
# 119583    102
# 122206    127
# 122207    110
# 123916    113
# 123917    101
# 124862     95
# 124863     79
# Name: pts, dtype: int64

# %%
grup.get_group("A")["pts"].mean()
# Out:
# 100.85661566726853

# %%
grup.get_group("H")["pts"].mean()
# Out:
# 104.60239475434761

# %%
grup.get_group("N")["pts"].mean()
# Out:
# 104.3157894736842

# %%
# Grouping dapat dilakukan pada lebih dari satu parameter

df[(df["year_id"] >= 2005) &
(df["year_id"] <= 2012) &
(df["fran_id"] == "Celtics")].groupby(by = ["year_id", "game_location"])["pts"].mean()
# Out:
# year_id  game_location
# 2005     A                101.227273
#          H                 99.200000
# 2006     A                 99.658537
#          H                 96.268293
# 2007     A                 95.780488
#          H                 95.853659
# 2008     A                 97.716981
#          H                100.181818
# 2009     A                 98.000000
#          H                104.061224
# 2010     A                 97.132075
#          H                 98.886792
# 2011     A                 93.804348
#          H                 98.888889
# 2012     A                 90.813953
#          H                 91.790698
# Name: pts, dtype: float64

# %%
sum_celtics = df[(df["year_id"] >= 2005) &
(df["year_id"] <= 2012) &
(df["fran_id"] == "Celtics")].groupby(by = ["year_id", "game_location"])["pts"].sum().reset_index()
print(sum_celtics)
# Out:
#     year_id game_location   pts
# 0      2005             A  4454
# 1      2005             H  4464
# 2      2006             A  4086
# 3      2006             H  3947
# 4      2007             A  3927
# 5      2007             H  3930
# 6      2008             A  5179
# 7      2008             H  5510
# 8      2009             A  4606
# 9      2009             H  5099
# 10     2010             A  5148
# 11     2010             H  5241
# 12     2011             A  4315
# 13     2011             H  4450
# 14     2012             A  3905
# 15     2012             H  3947

# %%
sum_celtics.iloc[:, 1:]
# Out:
#    game_location   pts
# 0              A  4454
# 1              H  4464
# 2              A  4086
# 3              H  3947
# 4              A  3927
# 5              H  3930
# 6              A  5179
# 7              H  5510
# 8              A  4606
# 9              H  5099
# 10             A  5148
# 11             H  5241
# 12             A  4315
# 13             H  4450
# 14             A  3905
# 15             H  3947

# %% [markdown]
# ## Column Manipulation

# %% [markdown]
# Mengubah nama kolom

# %%
nba = df.copy()
nba.head()
# Out:
#    gameorder       game_id lg_id  _iscopy  year_id  date_game  seasongame  \
# 0          1  194611010TRH   NBA        0     1947  11/1/1946           1
# 1          1  194611010TRH   NBA        1     1947  11/1/1946           1
# 2          2  194611020CHS   NBA        0     1947  11/2/1946           1
# 3          2  194611020CHS   NBA        1     1947  11/2/1946           2
# 4          3  194611020DTF   NBA        0     1947  11/2/1946           1
#
#    is_playoffs team_id  fran_id  pts      elo_i      elo_n  win_equiv opp_id  \
# 0            0     TRH  Huskies   66  1300.0000  1293.2767  40.294830    NYK
# 1            0     NYK   Knicks   68  1300.0000  1306.7233  41.705170    TRH
# 2            0     CHS    Stags   63  1300.0000  1309.6521  42.012257    NYK
# 3            0     NYK   Knicks   47  1306.7233  1297.0712  40.692783    CHS
# 4            0     DTF  Falcons   33  1300.0000  1279.6189  38.864048    WSC
#
# ...

# %%
# Mengubah nama

nba.rename(columns = {"loct": "location", "game_result": "result"}, inplace = True)
nba.head()
# Out:
#    gameorder       game_id lg_id  _iscopy  year_id  date_game  seasongame  \
# 0          1  194611010TRH   NBA        0     1947  11/1/1946           1
# 1          1  194611010TRH   NBA        1     1947  11/1/1946           1
# 2          2  194611020CHS   NBA        0     1947  11/2/1946           1
# 3          2  194611020CHS   NBA        1     1947  11/2/1946           2
# 4          3  194611020DTF   NBA        0     1947  11/2/1946           1
#
#    is_playoffs team_id  fran_id  pts      elo_i      elo_n  win_equiv opp_id  \
# 0            0     TRH  Huskies   66  1300.0000  1293.2767  40.294830    NYK
# 1            0     NYK   Knicks   68  1300.0000  1306.7233  41.705170    TRH
# 2            0     CHS    Stags   63  1300.0000  1309.6521  42.012257    NYK
# 3            0     NYK   Knicks   47  1306.7233  1297.0712  40.692783    CHS
# 4            0     DTF  Falcons   33  1300.0000  1279.6189  38.864048    WSC
#
# ...

# %%
nba.location

# Nama fungsi bawaan akan diprioritaskan daripada nama fungsi buatan sendiri
# Out:
# 0         H
# 1         A
# 2         H
# 3         A
# 4         H
#          ..
# 126309    H
# 126310    H
# 126311    A
# 126312    H
# 126313    A
# Name: location, Length: 126314, dtype: object

# %%
# Drop Column

nba.drop(labels = ["opp_elo_i", "opp_elo_n"], axis = 1, inplace = True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# d:\DokumenFaisal\DokumenFTDS014\Learning_Stuff\Phase_0\Week_1\Notebook_Day4PM.ipynb Cell 55 in <cell line: 3>()
#       <a href='vscode-notebook-cell:/d%3A/DokumenFaisal/DokumenFTDS014/Learning_Stuff/Phase_0/Week_1/Notebook_Day4PM.ipynb#ch0000064?line=0'>1</a> # Drop Column
# ----> <a href='vscode-notebook-cell:/d%3A/DokumenFaisal/DokumenFTDS014/Learning_Stuff/Phase_0/Week_1/Notebook_Day4PM.ipynb#ch0000064?line=2'>3</a> nba.drop(labels = ["opp_elo_i", "opp_elo_n"], axis = 1, inplace = True)
#       <a href='vscode-notebook-cell:/d%3A/DokumenFaisal/DokumenFTDS014/Learning_Stuff/Phase_0/Week_1/Notebook_Day4PM.ipynb#ch0000064?line=3'>4</a> nba
#
# File d:\DokumenFaisal\Tools\Anaconda3\lib\site-packages\pandas\util\_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
# ...

# %%
nba.head()
# Out:
#    gameorder       game_id lg_id  _iscopy  year_id  date_game  seasongame  \
# 0          1  194611010TRH   NBA        0     1947  11/1/1946           1
# 1          1  194611010TRH   NBA        1     1947  11/1/1946           1
# 2          2  194611020CHS   NBA        0     1947  11/2/1946           1
# 3          2  194611020CHS   NBA        1     1947  11/2/1946           2
# 4          3  194611020DTF   NBA        0     1947  11/2/1946           1
#
#    is_playoffs team_id  fran_id  pts  win_equiv opp_id  opp_fran  opp_pts  \
# 0            0     TRH  Huskies   66  40.294830    NYK    Knicks       68
# 1            0     NYK   Knicks   68  41.705170    TRH   Huskies       66
# 2            0     CHS    Stags   63  42.012257    NYK    Knicks       47
# 3            0     NYK   Knicks   47  40.692783    CHS     Stags       63
# 4            0     DTF  Falcons   33  38.864048    WSC  Capitols       50
#
#   location result  forecast notes
# 0        H      L  0.640065   NaN
# ...

# %%
# Create columns

nba["pts_diff"] = nba["pts"] - nba["opp_pts"]

# %%
nba.head()
# Out:
#    gameorder       game_id lg_id  _iscopy  year_id  date_game  seasongame  \
# 0          1  194611010TRH   NBA        0     1947  11/1/1946           1
# 1          1  194611010TRH   NBA        1     1947  11/1/1946           1
# 2          2  194611020CHS   NBA        0     1947  11/2/1946           1
# 3          2  194611020CHS   NBA        1     1947  11/2/1946           2
# 4          3  194611020DTF   NBA        0     1947  11/2/1946           1
#
#    is_playoffs team_id  fran_id  pts  win_equiv opp_id  opp_fran  opp_pts  \
# 0            0     TRH  Huskies   66  40.294830    NYK    Knicks       68
# 1            0     NYK   Knicks   68  41.705170    TRH   Huskies       66
# 2            0     CHS    Stags   63  42.012257    NYK    Knicks       47
# 3            0     NYK   Knicks   47  40.692783    CHS     Stags       63
# 4            0     DTF  Falcons   33  38.864048    WSC  Capitols       50
#
#   location result  forecast notes  pts_diff
# ...

# %% [markdown]
# # Menspesifikasi tipe data

# %%
nba.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 126314 entries, 0 to 126313
# Data columns (total 20 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   gameorder    126314 non-null  int64
#  1   game_id      126314 non-null  object
#  2   lg_id        126314 non-null  object
#  3   _iscopy      126314 non-null  int64
#  4   year_id      126314 non-null  int64
#  5   date_game    126314 non-null  object
#  6   seasongame   126314 non-null  int64
#  7   is_playoffs  126314 non-null  int64
#  8   team_id      126314 non-null  object
#  9   fran_id      126314 non-null  object
#  10  pts          126314 non-null  int64
#  11  win_equiv    126314 non-null  float64
#  12  opp_id       126314 non-null  object
#  13  opp_fran     126314 non-null  object
#  14  opp_pts      126314 non-null  int64
#  15  location     126314 non-null  object
#  16  result       126314 non-null  object
#  17  forecast     126314 non-null  float64
# ...

# %%
nba["date_game"] = pd.to_datetime(nba["date_game"])

# %%
nba["location"].nunique()
# Out:
# 3

# %%
nba["location"].value_counts()
# Out:
# H    63138
# A    63138
# N       38
# Name: location, dtype: int64

# %% [markdown]
# # Missing Value
#
# 1. Standard Missing Value (NaN -bisa dideteksi oleh fungsi)
# 2. Nonstandard Missing Value (format selain NaN, ditinjau dari dtype)
# 3. Invalid Missing Value (kesalahan input, ditinjau dengan .describe atau .nunique/.value_counts)

# %%
# Deteksi

nba.isnull().sum()
# Out:
# gameorder           0
# game_id             0
# lg_id               0
# _iscopy             0
# year_id             0
# date_game           0
# seasongame          0
# is_playoffs         0
# team_id             0
# fran_id             0
# pts                 0
# win_equiv           0
# opp_id              0
# opp_fran            0
# opp_pts             0
# location            0
# result              0
# forecast            0
# notes          120890
# pts_diff            0
# dtype: int64

# %%
nba.shape
# Out:
# (126314, 20)

# %%
nba.dropna()
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id  date_game  \
# 930           466  194801300BLB   NBA        1     1948 1948-01-30
# 931           466  194801300BLB   NBA        0     1948 1948-01-30
# 1084          543  194803230CHS   NBA        1     1948 1948-03-23
# 1085          543  194803230CHS   NBA        0     1948 1948-03-23
# 1088          545  194803250CHS   NBA        1     1948 1948-03-25
# ...           ...           ...   ...      ...      ...        ...
# 122207      61104  201401160ATL   NBA        0     2014 2014-01-16
# 123916      61959  201411120MIN   NBA        1     2015 2014-11-12
# 123917      61959  201411120MIN   NBA        0     2015 2014-11-12
# 124862      62432  201501150MIL   NBA        0     2015 2015-01-15
# 124863      62432  201501150MIL   NBA        1     2015 2015-01-15
#
#         seasongame  is_playoffs team_id       fran_id  pts  win_equiv opp_id  \
# 930             28            0     WSC      Capitols   71  47.065742    BLB
# ...

# %%
nba.dropna(axis=1).head()
# Out:
#    gameorder       game_id lg_id  _iscopy  year_id  date_game  seasongame  \
# 0          1  194611010TRH   NBA        0     1947 1946-11-01           1
# 1          1  194611010TRH   NBA        1     1947 1946-11-01           1
# 2          2  194611020CHS   NBA        0     1947 1946-11-02           1
# 3          2  194611020CHS   NBA        1     1947 1946-11-02           2
# 4          3  194611020DTF   NBA        0     1947 1946-11-02           1
#
#    is_playoffs team_id  fran_id  pts  win_equiv opp_id  opp_fran  opp_pts  \
# 0            0     TRH  Huskies   66  40.294830    NYK    Knicks       68
# 1            0     NYK   Knicks   68  41.705170    TRH   Huskies       66
# 2            0     CHS    Stags   63  42.012257    NYK    Knicks       47
# 3            0     NYK   Knicks   47  40.692783    CHS     Stags       63
# 4            0     DTF  Falcons   33  38.864048    WSC  Capitols       50
#
#   location result  forecast  pts_diff
# ...

# %%
# Bila ingin NaN diisi:

nba["notes"].fillna("no_notes", inplace = True)
nba
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id  date_game  \
# 0               1  194611010TRH   NBA        0     1947 1946-11-01
# 1               1  194611010TRH   NBA        1     1947 1946-11-01
# 2               2  194611020CHS   NBA        0     1947 1946-11-02
# 3               2  194611020CHS   NBA        1     1947 1946-11-02
# 4               3  194611020DTF   NBA        0     1947 1946-11-02
# ...           ...           ...   ...      ...      ...        ...
# 126309      63155  201506110CLE   NBA        0     2015 2015-06-11
# 126310      63156  201506140GSW   NBA        0     2015 2015-06-14
# 126311      63156  201506140GSW   NBA        1     2015 2015-06-14
# 126312      63157  201506170CLE   NBA        0     2015 2015-06-16
# 126313      63157  201506170CLE   NBA        1     2015 2015-06-16
#
#         seasongame  is_playoffs team_id    fran_id  pts  win_equiv opp_id  \
# 0                1            0     TRH    Huskies   66  40.294830    NYK
# ...

# %% [markdown]
# # Visualization

# %%
# Visualisasi plot
# Yang dipanggil pertama merupakan variabel x

nba[nba["year_id"] > 2010].groupby("year_id")["pts"].max().plot()
# Out:
# <AxesSubplot:xlabel='year_id'>

# %%
# Latihan

# 1. Siapkan list kosong untuk tempat penampung

hasil = []

# 2. Siapkan argumen looping
# 3. Masukkan hasil looping ke dalam list kosong

for baris in range(len(nba)):
    selisih = nba.iloc[baris, 10] - nba.iloc[baris, 14]
    hasil.append(selisih)

# 4. Buat list tersebut menjadi kolom baru

nba["diff_loop"] = hasil

# %%
nba.head()
# Out:
#    gameorder       game_id lg_id  _iscopy  year_id  date_game  seasongame  \
# 0          1  194611010TRH   NBA        0     1947 1946-11-01           1
# 1          1  194611010TRH   NBA        1     1947 1946-11-01           1
# 2          2  194611020CHS   NBA        0     1947 1946-11-02           1
# 3          2  194611020CHS   NBA        1     1947 1946-11-02           2
# 4          3  194611020DTF   NBA        0     1947 1946-11-02           1
#
#    is_playoffs team_id  fran_id  pts  win_equiv opp_id  opp_fran  opp_pts  \
# 0            0     TRH  Huskies   66  40.294830    NYK    Knicks       68
# 1            0     NYK   Knicks   68  41.705170    TRH   Huskies       66
# 2            0     CHS    Stags   63  42.012257    NYK    Knicks       47
# 3            0     NYK   Knicks   47  40.692783    CHS     Stags       63
# 4            0     DTF  Falcons   33  38.864048    WSC  Capitols       50
#
#   location result  forecast     notes  pts_diff  diff_loop
# ...

# %%
def wld(diff):
    if diff > 0:
        return "W"
    elif diff < 0:
        return "L"
    else:
        return "D"

keterangan = []
for idx in range(len(nba)):
    res = wld(nba.loc[idx, "pts_diff"])
    keterangan.append(res)

nba["status"] = keterangan

# %%
nba.head()
# Out:
#    gameorder       game_id lg_id  _iscopy  year_id  date_game  seasongame  \
# 0          1  194611010TRH   NBA        0     1947 1946-11-01           1
# 1          1  194611010TRH   NBA        1     1947 1946-11-01           1
# 2          2  194611020CHS   NBA        0     1947 1946-11-02           1
# 3          2  194611020CHS   NBA        1     1947 1946-11-02           2
# 4          3  194611020DTF   NBA        0     1947 1946-11-02           1
#
#    is_playoffs team_id  fran_id  pts  win_equiv opp_id  opp_fran  opp_pts  \
# 0            0     TRH  Huskies   66  40.294830    NYK    Knicks       68
# 1            0     NYK   Knicks   68  41.705170    TRH   Huskies       66
# 2            0     CHS    Stags   63  42.012257    NYK    Knicks       47
# 3            0     NYK   Knicks   47  40.692783    CHS     Stags       63
# 4            0     DTF  Falcons   33  38.864048    WSC  Capitols       50
#
#   location result  forecast     notes  pts_diff  diff_loop status
# ...
